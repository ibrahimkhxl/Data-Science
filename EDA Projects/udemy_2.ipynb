# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\ibrah\OneDrive\Desktop\DS\Pandas\Udemy\udemy_courses.csv")

# %%
df.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %%
df.tail()
# Out:
#       course_id                                       course_title  \
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 3673  https://www.udemy.com/easy-jquery-for-beginner...     True    100
# 3674  https://www.udemy.com/how-to-make-a-wordpress-...     True     25
# 3675  https://www.udemy.com/learn-and-build-using-po...     True     40
# 3676  https://www.udemy.com/css-animations-create-am...     True     50
# 3677  https://www.udemy.com/using-modx-cms-to-build-...     True     45
#
#       num_subscribers  num_reviews  num_lectures           level  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3678 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3678 non-null   int64
#  1   course_title         3678 non-null   object
#  2   url                  3678 non-null   object
#  3   is_paid              3678 non-null   bool
#  4   price                3678 non-null   int64
#  5   num_subscribers      3678 non-null   int64
#  6   num_reviews          3678 non-null   int64
#  7   num_lectures         3678 non-null   int64
#  8   level                3678 non-null   object
#  9   content_duration     3678 non-null   float64
#  10  published_timestamp  3678 non-null   object
#  11  subject              3678 non-null   object
# dtypes: bool(1), float64(1), int64(5), object(5)
# memory usage: 319.8+ KB

# %%
df.shape
# Out:
# (3678, 12)

# %%
df.isna().sum()
# Out:
# course_id              0
# course_title           0
# url                    0
# is_paid                0
# price                  0
# num_subscribers        0
# num_reviews            0
# num_lectures           0
# level                  0
# content_duration       0
# published_timestamp    0
# subject                0
# dtype: int64

# %%
df.loc[df.duplicated()]
# Out:
#       course_id                                       course_title  \
# 787      837322  Essentials of money value: Get a financial Life !
# 788     1157298  Introduction to Forex Trading Business For Beg...
# 894     1035638                 Understanding Financial Statements
# 1100    1084454                  CFA Level 2- Quantitative Methods
# 1473     185526                             MicroStation - Células
# 2561      28295  Learn Web Designing & HTML5/CSS3 Essentials in...
#
#                                                     url  is_paid  price  \
# 787    https://www.udemy.com/essentials-of-money-value/     True     20
# 788   https://www.udemy.com/introduction-to-forex-tr...     True     20
# 894   https://www.udemy.com/understanding-financial-...     True     25
# 1100  https://www.udemy.com/cfa-level-2-quantitative...     True     40
# 1473        https://www.udemy.com/microstation-celulas/     True     20
# ...

# %%
df.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %%
df.groupby(df['subject'])['course_id'].count().sort_values(ascending=False)
# Out:
# subject
# Web Development        1200
# Business Finance       1195
# Musical Instruments     680
# Graphic Design          603
# Name: course_id, dtype: int64

# %%
df['subject'].value_counts()
# Out:
# subject
# Web Development        1200
# Business Finance       1195
# Musical Instruments     680
# Graphic Design          603
# Name: count, dtype: int64

# %%
sns.countplot(df.subject,color = 'orange')
# Out:
# <Axes: xlabel='count', ylabel='subject'>

# %%
df.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %%
df.level.value_counts().sort_values(ascending = False)
# Out:
# level
# All Levels            1929
# Beginner Level        1270
# Intermediate Level     421
# Expert Level            58
# Name: count, dtype: int64

# %%
df.is_paid.value_counts()
# Out:
# is_paid
# True     3368
# False     310
# Name: count, dtype: int64

# %%
type(df.num_lectures[1])
x = df.num_lectures.max()

# %%
df.loc[df.num_lectures==x,['course_title','num_lectures']]
# Out:
#                                            course_title  num_lectures
# 2707  Back to School Web Development and Programming...           779

# %%
df.groupby(df.is_paid)['num_lectures'].sum()
# Out:
# is_paid
# False      6639
# True     140881
# Name: num_lectures, dtype: int64

# %%
df.shape
# Out:
# (3678, 12)

# %%
type(df.num_subscribers[1])
# Out:
# numpy.int64

# %%
df.groupby(df.is_paid)['num_subscribers'].sum()
# Out:
# is_paid
# False    3575525
# True     8183595
# Name: num_subscribers, dtype: int64

# %%
sns.barplot(x='is_paid',y='num_subscribers',data=df)
# Out:
# <Axes: xlabel='is_paid', ylabel='num_subscribers'>

# %%
df.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %%
df.groupby(df.level)['num_subscribers'].sum().sort_values(ascending=False)
# Out:
# level
# All Levels            6915076
# Beginner Level        4051843
# Intermediate Level     742005
# Expert Level            50196
# Name: num_subscribers, dtype: int64

# %%
x=df.num_subscribers.max()
x
# Out:
# 268923

# %%
df.loc[df.num_subscribers==x,['course_title']]
# Out:
#                               course_title
# 2827  Learn HTML5 Programming From Scratch

# %%
x=df.num_subscribers.sort_values(ascending=False).head().index

# %%
x
# Out:
# Index([2827, 3032, 3230, 2783, 3232], dtype='int64')

# %%
df.iloc[x]
# Out:
#       course_id                                       course_title  \
# 2827      41295               Learn HTML5 Programming From Scratch
# 3032      59014                     Coding for Entrepreneurs Basic
# 3230     625204                         The Web Developer Bootcamp
# 2783     173548  Build Your First Website in 1 Week with HTML5 ...
# 3232     764164              The Complete Web Developer Course 2.0
#
#                                                     url  is_paid  price  \
# 2827  https://www.udemy.com/learn-html5-programming-...    False      0
# 3032  https://www.udemy.com/coding-for-entrepreneurs...    False      0
# 3230  https://www.udemy.com/the-web-developer-bootcamp/     True    200
# 2783  https://www.udemy.com/build-your-first-website...    False      0
# 3232  https://www.udemy.com/the-complete-web-develop...     True    200
#
#       num_subscribers  num_reviews  num_lectures           level  \
# ...

# %%
df.groupby(df.num_subscribers)['course_title'].sum().tail()
# Out:
# num_subscribers
# 114512                The Complete Web Developer Course 2.0
# 120291    Build Your First Website in 1 Week with HTML5 ...
# 121584                           The Web Developer Bootcamp
# 161029                       Coding for Entrepreneurs Basic
# 268923                 Learn HTML5 Programming From Scratch
# Name: course_title, dtype: object

# %%
df.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %%
x=df.num_reviews.sort_values(ascending=False).head().index

# %%
p=df.num_reviews.max()
df.loc[df.num_reviews==p]
# Out:
#       course_id                course_title  \
# 3230     625204  The Web Developer Bootcamp
#
#                                                     url  is_paid  price  \
# 3230  https://www.udemy.com/the-web-developer-bootcamp/     True    200
#
#       num_subscribers  num_reviews  num_lectures       level  \
# 3230           121584        27445           342  All Levels
#
#       content_duration   published_timestamp          subject
# 3230              43.0  2015-11-02T21:13:27Z  Web Development

# %%
df.iloc[x]
# Out:
#       course_id                                       course_title  \
# 3230     625204                         The Web Developer Bootcamp
# 3232     764164              The Complete Web Developer Course 2.0
# 3204     756150  Angular 4 (formerly Angular 2) - The Complete ...
# 3247     364426          JavaScript: Understanding the Weird Parts
# 3254     705264                            Modern React with Redux
#
#                                                     url  is_paid  price  \
# 3230  https://www.udemy.com/the-web-developer-bootcamp/     True    200
# 3232  https://www.udemy.com/the-complete-web-develop...     True    200
# 3204  https://www.udemy.com/the-complete-guide-to-an...     True    190
# 3247       https://www.udemy.com/understand-javascript/     True    175
# 3254                 https://www.udemy.com/react-redux/     True    180
#
#       num_subscribers  num_reviews  num_lectures       level  \
# 3230           121584        27445           342  All Levels
# ...

# %%
# sns.barplot(x='price',y='num_reviews',data=df)

ax = sns.barplot(x="price",y='num_reviews', data=df)

ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha="right")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\ibrah\AppData\Local\Temp\ipykernel_35084\699592169.py:5: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha="right")

# %%
df.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %%
df.loc[df.course_title.str.contains('python', case=False, regex=True),['num_subscribers','course_title']].sort_values(by='num_subscribers',ascending=False).head(10)
# Out:
#       num_subscribers                                       course_title
# 2497            35267                        Web Programming with Python
# 2570            23412  Coding for Entrepreneurs: Learn Python, Django...
# 2528            17714        Learn Python and Django: Payment Processing
# 3200            11832  Python and Django Full Stack Web Developer Boo...
# 3507            10917  Fun and creative web engineering with Python a...
# 2553             7827  The Complete Ethical Hacking Course 2.0: Pytho...
# 3138             7489  Complete Python Web Course: Build 8 Python Web...
# 3197             7407  Try Django 1.9 | Build a Blog and Learn Python...
# 2681             6153  Python for Beginners: Python Programming Langu...
# 3203             5151                    REST APIs with Flask and Python

# %%
df.course_title.str.contains('python', case=False, regex=True)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3673    False
# 3674    False
# 3675    False
# 3676    False
# 3677    False
# Name: course_title, Length: 3678, dtype: bool

# %%
df.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %%
df['year'] = df['published_timestamp'][:4]
df.drop(['year'], axis=1,inplace = True)

# %%
df
# Out:
#       course_id                                       course_title  \
# 0       1070968                 Ultimate Investment Banking Course
# 1       1113822  Complete GST Course & Certification - Grow You...
# 2       1006314  Financial Modeling for Business Analysts and C...
# 3       1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4       1011058       How To Maximize Your Profits Trading Options
# ...         ...                                                ...
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 0     https://www.udemy.com/ultimate-investment-bank...     True    200
# ...

# %%
df['year'] = df['published_timestamp'].str.slice(0,4)

# %%
df.year.value_counts()
# Out:
# year
# 2016    1206
# 2015    1014
# 2017     715
# 2014     491
# 2013     202
# 2012      45
# 2011       5
# Name: count, dtype: int64

# %%
df.year = df.year.astype(int)

# %%
type(df.year[1])
# Out:
# numpy.int32

# %%
df.groupby(df.year)['course_title'].count().sort_values(ascending = False)
# Out:
# year
# 2016    1206
# 2015    1014
# 2017     715
# 2014     491
# 2013     202
# 2012      45
# 2011       5
# Name: course_title, dtype: int64

# %%
sns.countplot(x='year',data=df)
# Out:
# <Axes: xlabel='year', ylabel='count'>

# %%
df.groupby(df.year)['subject'].value_counts()
# Out:
# year  subject
# 2011  Web Development          5
# 2012  Web Development         19
#       Musical Instruments     10
#       Graphic Design          10
#       Business Finance         6
# 2013  Business Finance        84
#       Web Development         56
#       Musical Instruments     39
#       Graphic Design          23
# 2014  Business Finance       192
#       Musical Instruments    120
#       Web Development        113
#       Graphic Design          66
# 2015  Business Finance       339
#       Web Development        336
#       Musical Instruments    171
#       Graphic Design         168
# 2016  Web Development        448
#       Business Finance       349
#       Musical Instruments    228
#       Graphic Design         181
# 2017  Business Finance       225
#       Web Development        223
#       Graphic Design         155
#       Musical Instruments    112
# Name: count, dtype: int64
