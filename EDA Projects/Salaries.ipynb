# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv(r"C:\Users\ibrah\OneDrive\Desktop\Data Science\Pandas\archive\Salaries.csv")
# Out:
# C:\Users\ibrah\AppData\Local\Temp\ipykernel_109828\3034804156.py:1: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(r"C:\Users\ibrah\OneDrive\Desktop\Data Science\Pandas\archive\Salaries.csv")

# %%
data.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# 1  155966.02   245131.88  137811.38      NaN  538909.28         538909.28
# 2  212739.13   106088.18    16452.6      NaN  335279.91         335279.91
# 3    77916.0    56120.71   198306.9      NaN  332343.61         332343.61
# 4   134401.6      9737.0  182234.59      NaN  326373.19         326373.19
#
#    Year  Notes         Agency Status
# 0  2011    NaN  San Francisco    NaN
# ...

# %%
data.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB

# %%
data.shape
# Out:
# (148654, 13)

# %%
data.drop('Notes',axis =1)
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC       77916.0
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...

# %%
data.isna().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                605
# OvertimePay              0
# OtherPay                 0
# Benefits             36159
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              110535
# dtype: int64

# %%
data.describe(include = 'all')
# Out:
#                    Id EmployeeName          JobTitle   BasePay  OvertimePay  \
# count   148654.000000       148654            148654  148049.0     148654.0
# unique            NaN       110811              2159  109900.0      66555.0
# top               NaN    Kevin Lee  Transit Operator       0.0          0.0
# freq              NaN           13              7036     875.0      66103.0
# mean     74327.500000          NaN               NaN       NaN          NaN
# std      42912.857795          NaN               NaN       NaN          NaN
# min          1.000000          NaN               NaN       NaN          NaN
# 25%      37164.250000          NaN               NaN       NaN          NaN
# 50%      74327.500000          NaN               NaN       NaN          NaN
# 75%     111490.750000          NaN               NaN       NaN          NaN
# max     148654.000000          NaN               NaN       NaN          NaN
#
# ...

# %%
data.BasePay.unique()
# Out:
# array([167411.18, 155966.02, 212739.13, ..., '6.04', '15.50',
#        'Not Provided'], dtype=object)

# %%
na_val = ['Not Provided','nan','Missing','--','NaN',' ']

# %%
data.BasePay.isna().sum()
# Out:
# 605

# %%
data.replace(na_val,np.nan,inplace = True)

# %%
data.BasePay.isna().sum()
# Out:
# 609

# %%
data.BasePay = data.BasePay.astype(float)

# %%
data.BasePay.fillna(0,inplace = True)

# %%
data.BasePay = data.BasePay.replace(0,data.BasePay.mean())

# %%
data.BasePay.isna().sum()
# Out:
# 0

# %%
data.BasePay.mean()
# Out:
# 66901.09607102645

# %%
data.isna().sum()
# Out:
# Id                       0
# EmployeeName             2
# JobTitle                 0
# BasePay                  0
# OvertimePay              4
# OtherPay                 4
# Benefits             36163
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              110535
# dtype: int64

# %%
data.isna().sum()
# Out:
# Id                       0
# EmployeeName             2
# JobTitle                 0
# BasePay                  0
# OvertimePay              4
# OtherPay                 4
# Benefits             36163
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              110535
# dtype: int64

# %%
data.OvertimePay.unique()
data.OvertimePay.isna().sum()
# Out:
# 4

# %%
data.OvertimePay = data.OvertimePay.astype(float)

# %%
data.OvertimePay.fillna(data.OvertimePay.mean(),inplace = True)

# %%
data.OtherPay.unique()
data.OtherPay.isna().sum()
# Out:
# 4

# %%
data.OtherPay = data.OtherPay.astype(float)
data.OtherPay.isna().sum()
# Out:
# 4

# %%
data.OtherPay.fillna(data.OtherPay.mean(),inplace = True)

# %%
data.EmployeeName.unique()
# Out:
# array(['NATHANIEL FORD', 'GARY JIMENEZ', 'ALBERT PARDINI', ...,
#        'Charlene D Mccully', 'Not provided', 'Joe Lopez'], dtype=object)

# %%
data.EmployeeName.replace(na_val,np.nan,inplace = True)

# %%
data.EmployeeName = data.EmployeeName.dropna(axis = 0,how = 'any')

# %%
data.isna().sum()
# Out:
# Id                       0
# EmployeeName             2
# JobTitle                 0
# BasePay                  0
# OvertimePay              0
# OtherPay                 0
# Benefits             36163
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              110535
# dtype: int64

# %%
data.isna().sum()
# Out:
# Id                       0
# EmployeeName             2
# JobTitle                 0
# BasePay                  0
# OvertimePay              0
# OtherPay                 0
# Benefits             36163
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              110535
# dtype: int64

# %%
data.EmployeeName.isnull().sum()
# Out:
# 2

# %%
data.EmployeeName.dropna(how = 'any',inplace = True)

# %%
data.EmployeeName.isnull().sum()
# Out:
# 2

# %%
data.loc[data.EmployeeName == 'Not provided']
# Out:
#             Id  EmployeeName      JobTitle       BasePay  OvertimePay  \
# 148646  148647  Not provided  Not provided  66053.729288  5066.059886
# 148650  148651  Not provided  Not provided  66053.729288  5066.059886
# 148651  148652  Not provided  Not provided  66053.729288  5066.059886
# 148652  148653  Not provided  Not provided  66053.729288  5066.059886
#
#            OtherPay Benefits  TotalPay  TotalPayBenefits  Year  Notes  \
# 148646  3648.767297      NaN       0.0               0.0  2014    NaN
# 148650  3648.767297      NaN       0.0               0.0  2014    NaN
# 148651  3648.767297      NaN       0.0               0.0  2014    NaN
# 148652  3648.767297      NaN       0.0               0.0  2014    NaN
#
#                Agency Status
# 148646  San Francisco    NaN
# 148650  San Francisco    NaN
# 148651  San Francisco    NaN
# 148652  San Francisco    NaN

# %%
data.EmployeeName.replace('Not provided',np.nan,inplace = True)

# %%
data.EmployeeName.dropna(how = 'any',inplace = True)

# %%
data.EmployeeName.isna().sum()
# Out:
# 6

# %%
data.loc[data.Id == 148647]
# Out:
#             Id EmployeeName      JobTitle       BasePay  OvertimePay  \
# 148646  148647          NaN  Not provided  66053.729288  5066.059886
#
#            OtherPay Benefits  TotalPay  TotalPayBenefits  Year  Notes  \
# 148646  3648.767297      NaN       0.0               0.0  2014    NaN
#
#                Agency Status
# 148646  San Francisco    NaN

# %%
data.isna().sum()
# Out:
# Id                       0
# EmployeeName             6
# JobTitle                 0
# BasePay                  0
# OvertimePay              0
# OtherPay                 0
# Benefits             36163
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              110535
# dtype: int64

# %%
data = data[data['EmployeeName'].notna()]

# %%
data.isna().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                  0
# OvertimePay              0
# OtherPay                 0
# Benefits             36158
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148648
# Agency                   0
# Status              110529
# dtype: int64

# %%
data = data.drop(['Status','Notes','Id','Agency'],axis = 1)

# %%
data.isna().sum()
# Out:
# EmployeeName            0
# JobTitle                0
# BasePay                 0
# OvertimePay             0
# OtherPay                0
# Benefits            36158
# TotalPay                0
# TotalPayBenefits        0
# Year                    0
# dtype: int64

# %%
data.Benefits.isna().sum()
# Out:
# 36158

# %%
type(data.Benefits[1])
# Out:
# float

# %%
data.Benefits.replace(np.nan,0,inplace = True)

# %%
data.Benefits.isna().sum()
# Out:
# 0

# %%
data.Benefits = data.Benefits.astype(float)

# %%
data.Benefits.mean()
# Out:
# 18924.740892107526

# %%
data.describe(include = 'all')
# Out:
#        EmployeeName          JobTitle        BasePay    OvertimePay  \
# count        148648            148648  148648.000000  148648.000000
# unique       110809              2158            NaN            NaN
# top       Kevin Lee  Transit Operator            NaN            NaN
# freq             13              7036            NaN            NaN
# mean            NaN               NaN   66901.076103    5065.821161
# std             NaN               NaN   42221.436116   11454.266982
# min             NaN               NaN    -166.010000      -0.010000
# 25%             NaN               NaN   36206.247500       0.000000
# 50%             NaN               NaN   65656.620000       0.000000
# 75%             NaN               NaN   94611.000000    4657.597500
# max             NaN               NaN  319275.010000  245131.880000
#
#              OtherPay       Benefits       TotalPay  TotalPayBenefits  \
# count   148648.000000  148648.000000  148648.000000     148648.000000
# ...

# %% [markdown]
# ####  Find Occurrence of The Employee Names  (Top 5)

# %%
data.EmployeeName.value_counts().head(5)
# Out:
# EmployeeName
# Kevin Lee       13
# William Wong    11
# Richard Lee     11
# Steven Lee      11
# KEVIN LEE        9
# Name: count, dtype: int64

# %% [markdown]
# #### Find The Number of Unique Job Titles

# %%
len(data.JobTitle.unique())
# Out:
# 2158

# %% [markdown]
# #### Total Number of Job Titles Contain Captain

# %%
len(data.loc[data['JobTitle'].str.contains('Captain',case = False)])
# Out:
# 552

# %% [markdown]
# ##### Display All the Employee Names From Fire Department

# %%
data.head()
# Out:
#         EmployeeName                                        JobTitle  \
# 0     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       0.0  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       0.0  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       0.0  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       0.0  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       0.0  326373.19         326373.19
#
#    Year
# 0  2011
# 1  2011
# 2  2011
# 3  2011
# 4  2011

# %%
data.loc[data['JobTitle'].str.contains('Fire Department',case = False),['EmployeeName']]
# Out:
#                 EmployeeName
# 4            PATRICK GARDNER
# 6                  ALSON LEE
# 8             MICHAEL MORRIS
# 9         JOANNE HAYES-WHITE
# 10             ARTHUR KENNEY
# ...                      ...
# 32623           JAMES BARDEN
# 36162     Joanne Hayes-White
# 72926   Joanne M Hayes-White
# 102303        Robert E Evans
# 110535  Joanne M Hayes-White
#
# [226 rows x 1 columns]

# %% [markdown]
# ####  Find Minimum, Maximum, and Average BasePay

# %%
data['BasePay'].describe()
# Out:
# count    148648.000000
# mean      66901.076103
# std       42221.436116
# min        -166.010000
# 25%       36206.247500
# 50%       65656.620000
# 75%       94611.000000
# max      319275.010000
# Name: BasePay, dtype: float64

# %% [markdown]
# ####  Find Job Title of ALBERT PARDINI

# %%
data.loc[data['EmployeeName'] == 'ALBERT PARDINI' , ['JobTitle']]
# Out:
#                           JobTitle
# 2  CAPTAIN III (POLICE DEPARTMENT)

# %% [markdown]
# #### How Much ALBERT PARDINI Make (Include Benefits)?

# %%
data.head()
# Out:
#         EmployeeName                                        JobTitle  \
# 0     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       0.0  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       0.0  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       0.0  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       0.0  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       0.0  326373.19         326373.19
#
#    Year
# 0  2011
# 1  2011
# 2  2011
# 3  2011
# 4  2011

# %%
x = data.loc[data.EmployeeName == 'ALBERT PARDINI' ,   ['TotalPay'] + ['Benefits'] ] 
x
# Out:
#     TotalPay  Benefits
# 2  335279.91       0.0

# %% [markdown]
# #### Display Name of The Person Having The Highest BasePay

# %%
maxPay = data.BasePay.max()

# %%
data.loc[data['BasePay'] == maxPay ,['EmployeeName']]
# Out:
#          EmployeeName
# 72925  Gregory P Suhr

# %% [markdown]
# #### Find Average BasePay of Employee Having Job Title ACCOUNTANT

# %%
AvgPay = data.BasePay.mean()

# %%
data.loc[data['JobTitle'].str.contains('ACCOUNTANT') , ['BasePay']].mean()
# Out:
# BasePay    65894.790388
# dtype: float64

# %%
data[data['JobTitle'] == 'ACCOUNTANT']['BasePay'].mean()
# Out:
# 59853.91785761567

# %% [markdown]
# ####  Find Top 5 Most Common Jobs

# %%
data.JobTitle.value_counts().head(5)
# Out:
# JobTitle
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: count, dtype: int64

# %% [markdown]
# #### Find Average BasePay of All Employee Per Year

# %%
data.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='object')

# %%
gb1 = data.BasePay.groupby(data.Year)
for year,paye in gb1:
    print(year)
    #print(gb1.get_group(year).mean())
    print(paye.mean())
# Out:
# 2011
# 64421.8295795733
# 2012
# 66190.542752645
# 2013
# 69572.49519383309
# 2014
# 67302.60730912987

# %% [markdown]
# #### Find Average BasePay of All Employee Per JobTitle

# %%
gb = data.BasePay.groupby(data.JobTitle)

# %%
gb.get_group('GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY').mean()
# Out:
# 199119.15

# %%
for name,row in gb:
     print(name)
#     print(row.mean())
     print(gb.get_group(name).mean())
# Out:
# ACCOUNT CLERK
# 43300.8065060241
# ACCOUNTANT
# 59853.91785761567
# ACCOUNTANT INTERN
# 28732.663958333334
# ACPO,JuvP, Juv Prob (SFERS)
# 62290.78
# ACUPUNCTURIST
# 66374.4
# ADMINISTRATIVE ANALYST
# 64856.13890942104
# ADMINISTRATIVE ANALYST II
# 59373.71000000001
# ADMINISTRATIVE ANALYST III
# 92698.515
# ADMINISTRATIVE ENGINEER
# 120913.161
# ADMINISTRATIVE SERVICES MANAGER
# 75555.03333333334
# ADMINISTRATOR, SFGH MEDICAL CENTER
# 245124.44
# AFFIRMATIVE ACTION SPECIALIST
# 68177.31666666667
# AGRICULTURAL INSPECTOR
# 53274.1
# AIRPORT ASSISTANT DEPUTY DIRECTOR, BUSINESS ADMINI
# 1927.5
# AIRPORT ASSISTANT DEPUTY DIRECTOR, OPERATIONS
# 15420.0
# AIRPORT COMMUNICATIONS OPERATOR
# 67643.14259259259
# AIRPORT COMMUNICATIONS SUPERVISOR
# 86585.825
# AIRPORT ECONOMIC PLANNER
# 108145.59076923077
# AIRPORT ELECTRICIAN
# 95488.67176470588
# AIRPORT ELECTRICIAN SUPERVISOR
# 104203.725
# AIRPORT EMERGENCY PLANNING COORDINATOR
# 75865.935
# AIRPORT MECHANICAL MAINTENANCE SUPERVISOR
# ...
