# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\ibrah\OneDrive\Desktop\DS\Pandas\Udemy\udemy_courses.csv")
df.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %%
df.shape
# Out:
# (3678, 12)

# %%
3678-6
# Out:
# 3672

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3678 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3678 non-null   int64
#  1   course_title         3678 non-null   object
#  2   url                  3678 non-null   object
#  3   is_paid              3678 non-null   bool
#  4   price                3678 non-null   int64
#  5   num_subscribers      3678 non-null   int64
#  6   num_reviews          3678 non-null   int64
#  7   num_lectures         3678 non-null   int64
#  8   level                3678 non-null   object
#  9   content_duration     3678 non-null   float64
#  10  published_timestamp  3678 non-null   object
#  11  subject              3678 non-null   object
# dtypes: bool(1), float64(1), int64(5), object(5)
# memory usage: 319.8+ KB

# %%
df.describe(include = "all")
# Out:
#            course_id                   course_title  \
# count   3.678000e+03                           3678
# unique           NaN                           3663
# top              NaN  Acoustic Blues Guitar Lessons
# freq             NaN                              3
# mean    6.759720e+05                            NaN
# std     3.432732e+05                            NaN
# min     8.324000e+03                            NaN
# 25%     4.076925e+05                            NaN
# 50%     6.879170e+05                            NaN
# 75%     9.613555e+05                            NaN
# max     1.282064e+06                            NaN
#
#                                                       url is_paid  \
# count                                                3678    3678
# unique                                               3672       2
# top     https://www.udemy.com/cfa-level-2-quantitative...    True
# freq                                                    2    3368
# ...

# %%
df.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# course_id              0
# course_title           0
# url                    0
# is_paid                0
# price                  0
# num_subscribers        0
# num_reviews            0
# num_lectures           0
# level                  0
# content_duration       0
# published_timestamp    0
# subject                0
# dtype: int64

# %%
sns.heatmap(df.isna())
# Out:
# <Axes: >

# %%
df.duplicated().any()
# Out:
# True

# %%
df[df.duplicated]
# Out:
#       course_id                                       course_title  \
# 787      837322  Essentials of money value: Get a financial Life !
# 788     1157298  Introduction to Forex Trading Business For Beg...
# 894     1035638                 Understanding Financial Statements
# 1100    1084454                  CFA Level 2- Quantitative Methods
# 1473     185526                             MicroStation - Células
# 2561      28295  Learn Web Designing & HTML5/CSS3 Essentials in...
#
#                                                     url  is_paid  price  \
# 787    https://www.udemy.com/essentials-of-money-value/     True     20
# 788   https://www.udemy.com/introduction-to-forex-tr...     True     20
# 894   https://www.udemy.com/understanding-financial-...     True     25
# 1100  https://www.udemy.com/cfa-level-2-quantitative...     True     40
# 1473        https://www.udemy.com/microstation-celulas/     True     20
# ...

# %%
df.shape
# Out:
# (3678, 12)

# %%
x = df[df.duplicated()].index
x
# Out:
# Index([787, 788, 894, 1100, 1473, 2561], dtype='int64')

# %%
df.drop(x,inplace = True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %%
df.groupby(df.subject)['course_id'].count().sort_values(ascending = False)
# Out:
# subject
# Web Development        1199
# Business Finance       1191
# Musical Instruments     680
# Graphic Design          602
# Name: course_id, dtype: int64

# %%
df.subject.value_counts()
# Out:
# subject
# Web Development        1199
# Business Finance       1191
# Musical Instruments     680
# Graphic Design          602
# Name: count, dtype: int64

# %%
plt.figure(figsize = (12,8))
sns.countplot(data = df,x = 'subject')
# Out:
# <Axes: xlabel='subject', ylabel='count'>

# %%
plt.hist(df.subject)
plt.xticks( )
plt.show()

# %%
df.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %%
df.level.value_counts()
# Out:
# level
# All Levels            1925
# Beginner Level        1268
# Intermediate Level     421
# Expert Level            58
# Name: count, dtype: int64

# %%
df.groupby(df.level)['course_id'].count().sort_values(ascending = False)
# Out:
# level
# All Levels            1925
# Beginner Level        1268
# Intermediate Level     421
# Expert Level            58
# Name: course_id, dtype: int64

# %%
sns.countplot(df.level)
# Out:
# <Axes: xlabel='count', ylabel='level'>

# %%
plt.hist(data = df,x = 'level')
plt.show()

# %%
sns.distplot(df.num_subscribers)
plt.show()
# Out:
# C:\Users\ibrah\AppData\Local\Temp\ipykernel_1652\3714910852.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.num_subscribers)

# %%
df.is_paid.value_counts()
# Out:
# is_paid
# True     3362
# False     310
# Name: count, dtype: int64

# %%
x = df.groupby(df.is_paid)['num_lectures'].sum().sort_values(ascending = False)
# Out:
# is_paid
# True     140756
# False      6639
# Name: num_lectures, dtype: int64

# %%
sns.barplot(data = df, x= 'is_paid',y = 'num_lectures')
# Out:
# <Axes: xlabel='is_paid', ylabel='num_lectures'>

# %%
num = np.array(df.groupby(df.is_paid)['num_lectures'].mean())
# Out:
# array([21.41612903, 41.86674598])

# %%
df.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %%
df.groupby(df.is_paid)['num_subscribers'].sum()
# Out:
# is_paid
# False    3575525
# True     8140310
# Name: num_subscribers, dtype: int64

# %%
sns.barplot(data = df, x = 'is_paid',y = 'num_subscribers')
# Out:
# <Axes: xlabel='is_paid', ylabel='num_subscribers'>

# %% [markdown]
# ### Which Level Has The Highest Number of Subscribers?

# %%
df.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %%
df.groupby(df.level)['num_subscribers'].sum().sort_values(ascending = False)
# Out:
# level
# All Levels            6871791
# Beginner Level        4051843
# Intermediate Level     742005
# Expert Level            50196
# Name: num_subscribers, dtype: int64

# %%
plt.pie(df.num_subscribers,labels = df.level)
plt.show()

# %%
gb = df.groupby(df.level)['num_subscribers']
gb.sum()
# Out:
# level
# All Levels            6871791
# Beginner Level        4051843
# Expert Level            50196
# Intermediate Level     742005
# Name: num_subscribers, dtype: int64

# %%
gb.get_group('All Levels').sum()
# Out:
# 6871791

# %%
arr = []
brr = []

# %%
for x,y in gb:
    print(x)
    #r = np.array(x)
    arr.append(x)
    #s = np.array(gb.get_group(x).sum())
    brr.append(gb.get_group(x).sum())
# Out:
# All Levels
# Beginner Level
# Expert Level
# Intermediate Level

# %%
arr
# Out:
# ['All Levels', 'Beginner Level', 'Expert Level', 'Intermediate Level']

# %%
brr
# Out:
# [6871791, 4051843, 50196, 742005]

# %%
plt.pie(brr,labels = arr,radius = 1.3,autopct = '%0.1f%%')
plt.show()

# %%
sns.barplot(data = df,x= 'level',y = 'num_subscribers')
# Out:
# <Axes: xlabel='level', ylabel='num_subscribers'>

# %%
sns.barplot(x = arr,y = brr)
# Out:
# <Axes: >

# %%
df.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %%
mr = df.num_reviews.max()
ms= df.num_subscribers.max()
df.loc[(df.num_reviews == mr)]
# Out:
#       course_id                course_title  \
# 3230     625204  The Web Developer Bootcamp
#
#                                                     url  is_paid  price  \
# 3230  https://www.udemy.com/the-web-developer-bootcamp/     True    200
#
#       num_subscribers  num_reviews  num_lectures       level  \
# 3230           121584        27445           342  All Levels
#
#       content_duration   published_timestamp          subject
# 3230              43.0  2015-11-02T21:13:27Z  Web Development

# %%
df.iloc[inx]
# Out:
#       course_id                            course_title  \
# 3236     720356  Projects in Node.js - Learn by Example
#
#                                             url  is_paid  price  \
# 3236  https://www.udemy.com/projects-in-nodejs/     True    195
#
#       num_subscribers  num_reviews  num_lectures       level  \
# 3236              869           99            38  All Levels
#
#       content_duration   published_timestamp          subject
# 3236               5.0  2016-04-24T18:29:26Z  Web Development

# %%
print(arr)
# Out:
# ['All Levels', 'Beginner Level', 'Expert Level', 'Intermediate Level']

# %%
df.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %%
df['Year'] = df.published_timestamp.str.slice(0,4)

# %%
type(df.Year[1])
# Out:
# str

# %%
df['Year'] = df['Year'].astype(int)

# %%
df.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %%
type(df.Year[1])
# Out:
# numpy.int32

# %%
df.groupby(df.Year)['course_title'].count().sort_values(ascending = False)
# Out:
# Year
# 2016    1204
# 2015    1014
# 2017     713
# 2014     490
# 2013     201
# 2012      45
# 2011       5
# Name: course_title, dtype: int64

# %%
df.Year.value_counts()
# Out:
# Year
# 2016    1204
# 2015    1014
# 2017     713
# 2014     490
# 2013     201
# 2012      45
# 2011       5
# Name: count, dtype: int64

# %%
plt.hist(df.Year,rwidth = 0.90)
# plt.xticks([2011,2012,2013,2014,2015,2016,2017])
plt.show()

# %%
sns.distplot(df.Year)
plt.show()
# Out:
# C:\Users\ibrah\AppData\Local\Temp\ipykernel_1652\1080123286.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Year)

# %%
sns.countplot(data = df , x='Year')
plt.grid()

# %%
df.groupby(df.Year)['subject'].value_counts()
# Out:
# Year  subject
# 2011  Web Development          5
# 2012  Web Development         19
#       Musical Instruments     10
#       Graphic Design          10
#       Business Finance         6
# 2013  Business Finance        84
#       Web Development         55
#       Musical Instruments     39
#       Graphic Design          23
# 2014  Business Finance       192
#       Musical Instruments    120
#       Web Development        113
#       Graphic Design          65
# 2015  Business Finance       339
#       Web Development        336
#       Musical Instruments    171
#       Graphic Design         168
# 2016  Web Development        448
#       Business Finance       347
#       Musical Instruments    228
#       Graphic Design         181
# 2017  Web Development        223
#       Business Finance       223
#       Graphic Design         155
#       Musical Instruments    112
# Name: count, dtype: int64

# %%
plt.figure(figsize = (9,5))
sns.countplot(data = df, x = df.subject, hue = df.Year)
# Out:
# <Axes: xlabel='subject', ylabel='count'>

# %%
plt.figure(figsize = (9,5))
sns.countplot(data = df, x = df.Year, hue = df.subject)
# Out:
# <Axes: xlabel='Year', ylabel='count'>
