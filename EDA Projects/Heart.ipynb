# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\ibrah\Data Science\Pandas\archive\heart.csv")

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df.tail()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %%
df.shape
# Out:
# (1025, 14)

# %%
df.describe(include = 'all')
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
df.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 723

# %%
df.loc[df.duplicated()]
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 15     34    0   1       118   210    0        1      192      0      0.7
# 31     50    0   1       120   244    0        1      162      0      1.1
# 43     46    1   0       120   249    0        0      144      0      0.8
# 55     55    1   0       140   217    0        1      111      1      5.6
# 61     66    0   2       146   278    0        0      152      0      0.0
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 15        2   0     2       1
# ...

# %%
df.drop_duplicates(keep="last",inplace = True)

# %%
df.shape
# Out:
# (302, 14)

# %%
x = df.corr()
plt.figure(figsize  = (17,6))
sns.heatmap(x,annot = True)
# Out:
# <Axes: >

# %%
df.head()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 138   47    1   2       138   257    0        0      156      0      0.0
# 155   54    1   1       108   309    0        1      156      0      0.0
# 283   64    1   3       110   211    0        0      144      1      1.8
# 293   59    1   2       150   212    1        1      157      0      1.6
# 295   67    1   0       100   299    0        0      125      1      0.9
#
#      slope  ca  thal  target
# 138      2   0     2       1
# 155      2   0     3       1
# 283      1   0     2       1
# 293      2   0     2       1
# 295      1   2     2       0

# %%
df.target.value_counts()
# Out:
# target
# 1    164
# 0    138
# Name: count, dtype: int64

# %%
sns.countplot(data = df,x = 'target' ,color = 'orange')
# Out:
# <Axes: xlabel='target', ylabel='count'>

# %%
plt.hist(df.target,bins = [0,0.1,1,1.1],rwidth = 0.90,color = "red")
# Out:
# (array([138.,   0., 164.]),
#  array([0. , 0.1, 1. , 1.1]),
#  <BarContainer object of 3 artists>)

# %%
df.sex.value_counts()
# Out:
# sex
# 1    206
# 0     96
# Name: count, dtype: int64

# %%
plt.hist(df.sex,rwidth = 0.90,color = "red")
plt.xticks([0,1],['female','male'])
# Out:
# ([<matplotlib.axis.XTick at 0x19d33e5fa90>,
# ...
#  [Text(0, 0, 'female'), Text(1, 0, 'male')])

# %%
men = df.loc[df.sex == 1,'sex']
men = np.array(men)

wmen = df.loc[df.sex == 0,'sex']
wmen = np.array(wmen)

# %%
plt.hist([men,wmen],bins = [0,0.1,1,1.1],rwidth = 0.954,color = ["pink",'blue'],label=['female','male'])
plt.legend()
# plt.xticks([0,1],['Female','Male'])

# %%
df.head()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 138   47    1   2       138   257    0        0      156      0      0.0
# 155   54    1   1       108   309    0        1      156      0      0.0
# 283   64    1   3       110   211    0        0      144      1      1.8
# 293   59    1   2       150   212    1        1      157      0      1.6
# 295   67    1   0       100   299    0        0      125      1      0.9
#
#      slope  ca  thal  target
# 138      2   0     2       1
# 155      2   0     3       1
# 283      1   0     2       1
# 293      2   0     2       1
# 295      1   2     2       0

# %%
df.age.value_counts()
# Out:
# age
# 58    19
# 57    17
# 54    16
# 59    14
# 52    13
# 51    12
# 62    11
# 44    11
# 60    11
# 56    11
# 64    10
# 41    10
# 67     9
# 63     9
# 43     8
# 61     8
# 65     8
# 42     8
# 45     8
# 53     8
# 55     8
# 50     7
# 66     7
# 48     7
# 46     7
# 47     5
# 49     5
# 39     4
# 70     4
# 35     4
# 68     4
# 69     3
# 40     3
# 71     3
# 34     2
# 37     2
# 38     2
# 77     1
# 29     1
# 74     1
# 76     1
# Name: count, dtype: int64

# %%
plt.figure(figsize = (20,10))
sns.countplot(data = df,x = 'age',width=0.90)
plt.xticks(rotation = 80,fontsize = 18)
plt.show()

# %%
df.age.min()
# Out:
# 29

# %%
plt.hist(df.age,rwidth = 0.90,bins = [25,30,35,40,45,50,55,60,65,70,75,80],
        orientation = 'vertical',color='orange')
plt.xticks([25,30,35,40,45,50,55,60,65,70,75,80])
plt.xlabel('Age')
plt.show()

# %%
sns.distplot(df.age)
plt.show()
# Out:
# C:\Users\ibrah\AppData\Local\Temp\ipykernel_62732\3736774311.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.age)

# %%
df.head()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 138   47    1   2       138   257    0        0      156      0      0.0
# 155   54    1   1       108   309    0        1      156      0      0.0
# 283   64    1   3       110   211    0        0      144      1      1.8
# 293   59    1   2       150   212    1        1      157      0      1.6
# 295   67    1   0       100   299    0        0      125      1      0.9
#
#      slope  ca  thal  target
# 138      2   0     2       1
# 155      2   0     3       1
# 283      1   0     2       1
# 293      2   0     2       1
# 295      1   2     2       0

# %%
df.cp.value_counts()
# Out:
# cp
# 0    143
# 2     86
# 1     50
# 3     23
# Name: count, dtype: int64

# %%
plt.hist(df.cp,bins=[0,1,2,3,4],rwidth = 0.70)
plt.xticks([0,1,2,3],['typical angia','atypical angina','non-anginal pain','asymptomatic'])
plt.xticks(rotation = 70)
plt.xlabel('Type of pain')
plt.title('Chest pain')
plt.grid()
plt.show()

# %%
df.head()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 138   47    1   2       138   257    0        0      156      0      0.0
# 155   54    1   1       108   309    0        1      156      0      0.0
# 283   64    1   3       110   211    0        0      144      1      1.8
# 293   59    1   2       150   212    1        1      157      0      1.6
# 295   67    1   0       100   299    0        0      125      1      0.9
#
#      slope  ca  thal  target
# 138      2   0     2       1
# 155      2   0     3       1
# 283      1   0     2       1
# 293      2   0     2       1
# 295      1   2     2       0

# %%
sns.distplot([df.target,df.cp])
# Out:
# C:\Users\ibrah\AppData\Local\Temp\ipykernel_62732\2193059224.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([df.target,df.cp])
# <Axes: ylabel='Density'>

# %%
sns.countplot(data = df,x = 'cp',hue = 'target')
# Out:
# <Axes: xlabel='cp', ylabel='count'>

# %%
df.head()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 138   47    1   2       138   257    0        0      156      0      0.0
# 155   54    1   1       108   309    0        1      156      0      0.0
# 283   64    1   3       110   211    0        0      144      1      1.8
# 293   59    1   2       150   212    1        1      157      0      1.6
# 295   67    1   0       100   299    0        0      125      1      0.9
#
#      slope  ca  thal  target
# 138      2   0     2       1
# 155      2   0     3       1
# 283      1   0     2       1
# 293      2   0     2       1
# 295      1   2     2       0

# %%
df.fbs.value_counts()
# Out:
# fbs
# 0    257
# 1     45
# Name: count, dtype: int64

# %%
sns.countplot(data = df,x = 'fbs',hue = 'target')
plt.legend(labels= ['No-Disease','Disease'])
plt.show()

# %%
df.head()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 138   47    1   2       138   257    0        0      156      0      0.0
# 155   54    1   1       108   309    0        1      156      0      0.0
# 283   64    1   3       110   211    0        0      144      1      1.8
# 293   59    1   2       150   212    1        1      157      0      1.6
# 295   67    1   0       100   299    0        0      125      1      0.9
#
#      slope  ca  thal  target
# 138      2   0     2       1
# 155      2   0     3       1
# 283      1   0     2       1
# 293      2   0     2       1
# 295      1   2     2       0

# %%
sns.distplot(df['trestbps'] )
# Out:
# C:\Users\ibrah\AppData\Local\Temp\ipykernel_62732\3505127241.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['trestbps'] )
# <Axes: xlabel='trestbps', ylabel='Density'>

# %%
plt.hist(df.trestbps,rwidth = 0.90,color = 'red')
plt.grid()
plt.show()

# %%
df.head(10)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 138   47    1   2       138   257    0        0      156      0      0.0
# 155   54    1   1       108   309    0        1      156      0      0.0
# 283   64    1   3       110   211    0        0      144      1      1.8
# 293   59    1   2       150   212    1        1      157      0      1.6
# 295   67    1   0       100   299    0        0      125      1      0.9
# 302   55    0   1       132   342    0        1      166      0      1.2
# 326   54    1   1       192   283    0        0      195      0      0.0
# 330   37    0   2       120   215    0        1      170      0      0.0
# 350   66    1   0       120   302    0        0      151      0      0.4
# 359   53    0   2       128   216    0        0      115      0      0.0
#
#      slope  ca  thal  target
# 138      2   0     2       1
# 155      2   0     3       1
# 283      1   0     2       1
# 293      2   0     2       1
# ...

# %%
df.groupby(df.sex)['trestbps'].mean()
# Out:
# sex
# 0    133.083333
# 1    130.912621
# Name: trestbps, dtype: float64

# %%
plt.figure(figsize = (15,8))
sns.barplot(x = 'sex',y = 'trestbps',data = df)
# Out:
# <Axes: xlabel='sex', ylabel='trestbps'>

# %%
sns.countplot(data = df, x = 'sex', hue = 'trestbps')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
df.head()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 138   47    1   2       138   257    0        0      156      0      0.0
# 155   54    1   1       108   309    0        1      156      0      0.0
# 283   64    1   3       110   211    0        0      144      1      1.8
# 293   59    1   2       150   212    1        1      157      0      1.6
# 295   67    1   0       100   299    0        0      125      1      0.9
#
#      slope  ca  thal  target
# 138      2   0     2       1
# 155      2   0     3       1
# 283      1   0     2       1
# 293      2   0     2       1
# 295      1   2     2       0

# %%
sns.distplot(df.chol)
plt.show()
# Out:
# C:\Users\ibrah\AppData\Local\Temp\ipykernel_62732\3140104783.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.chol)

# %%
df.chol.max()
# Out:
# 564

# %%
plt.hist(df.chol,rwidth = 0.90,bins = [100,150,200,250,300,350,400,450,500,550,600])
# Out:
# (array([  5.,  44., 124.,  85.,  36.,   4.,   3.,   0.,   0.,   1.]),
#  array([100., 150., 200., 250., 300., 350., 400., 450., 500., 550., 600.]),
#  <BarContainer object of 10 artists>)

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0
