# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\ibrah\OneDrive\Desktop\Data Science\Pandas\archive\Ecommerce Purchases")
df.head(10)
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# 5  7502 Powell Mission Apt. 768\nTravisland, VA 3...  21 XT       PM
# 6     93971 Conway Causeway\nAndersonburgh, AZ 75107  96 Xt       AM
# 7  260 Rachel Plains Suite 366\nCastroberg, WV 24...  96 pG       PM
# 8            2129 Dylan Burg\nNew Michelle, ME 28650  45 JN       PM
# 9    3795 Dawson Extensions\nLake Tinafort, ID 88739  15 Ug       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# ...

# %%
df.dtypes
# Out:
# Address              object
# Lot                  object
# AM or PM             object
# Browser Info         object
# Company              object
# Credit Card           int64
# CC Exp Date          object
# CC Security Code      int64
# CC Provider          object
# Email                object
# Job                  object
# IP Address           object
# Language             object
# Purchase Price      float64
# dtype: object

# %%
df.isna().sum()
# Out:
# Address             0
# Lot                 0
# AM or PM            0
# Browser Info        0
# Company             0
# Credit Card         0
# CC Exp Date         0
# CC Security Code    0
# CC Provider         0
# Email               0
# Job                 0
# IP Address          0
# Language            0
# Purchase Price      0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
len(df)
# Out:
# 10000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           10000 non-null  object
#  1   Lot               10000 non-null  object
#  2   AM or PM          10000 non-null  object
#  3   Browser Info      10000 non-null  object
#  4   Company           10000 non-null  object
#  5   Credit Card       10000 non-null  int64
#  6   CC Exp Date       10000 non-null  object
#  7   CC Security Code  10000 non-null  int64
#  8   CC Provider       10000 non-null  object
#  9   Email             10000 non-null  object
#  10  Job               10000 non-null  object
#  11  IP Address        10000 non-null  object
#  12  Language          10000 non-null  object
#  13  Purchase Price    10000 non-null  float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.1+ MB

# %%
df['Purchase Price'].max()
# Out:
# 99.99

# %%
df['Purchase Price'].min()
# Out:
# 0.0

# %%
df['Purchase Price'].mean()
# Out:
# 50.347302

# %%
len(df.loc[df.Language == 'fr'])
# Out:
# 1097

# %%
df.head()
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# ...

# %%
len(df.loc[df.Language == 'fr'])
# Out:
# 1097

# %%
len(df.loc[df.Job.str.contains('engineer')])
# Out:
# 531

# %% [markdown]
# #### Q10. Find The Email of the person with the following IP Address: 132.207.160.22

# %%
type(df['IP Address'][1])
# Out:
# str

# %%
df.loc[df['IP Address'] == '132.207.160.22' , ['Email']]
# Out:
#                             Email
# 2  amymiller@morales-harrison.com

# %%
df.loc[df['IP Address'].str.contains('132.207.160.22') , ['Email']]
# Out:
#                             Email
# 2  amymiller@morales-harrison.com

# %%
type(df['Purchase Price'][1])
# Out:
# numpy.float64

# %% [markdown]
# #### Q11. How many People have Mastercard as their Credit Card Provider and made a purchase above 50?

# %%
len(df.loc[ (df['CC Provider'] == 'Mastercard') & (df['Purchase Price'] >= 50) ])
# Out:
# 405

# %% [markdown]
# #### Q12. Find the email of the person with the following Credit Card Number: 4664825258997302

# %%
type(df['Credit Card'][1])
# Out:
# numpy.int64

# %%
df.loc[df['Credit Card'] == 4664825258997302 , ['Email'] ]
# Out:
#                   Email
# 9992  bberry@wright.net

# %% [markdown]
# To typecast it into String

# %%
zf = pd.read_csv(r"C:\Users\ibrah\OneDrive\Desktop\Data Science\Pandas\archive\Ecommerce Purchases")

# %%
zf['Credit Card'] = zf['Credit Card'].astype(str)

# %%
zf.loc[zf['Credit Card'].str.contains('4664825258997302') , ['Email']]
# Out:
#                   Email
# 9992  bberry@wright.net

# %% [markdown]
# #### Q13. How many people purchase during the AM and how many people purchase during PM?

# %%
df.shape
# Out:
# (10000, 14)

# %%
df['Purchase Price'].isna().sum()
# Out:
# 0

# %%
len(df.loc[df['AM or PM'] == 'PM'])
# Out:
# 5068

# %%
len(df.loc[df['AM or PM'] == 'AM'])
# Out:
# 4932

# %% [markdown]
# #### Q14. How many people have a credit card that expires in 2020?

# %%
df.head()
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# ...

# %%
type(df['CC Exp Date'][1])
# Out:
# str

# %%
kf = pd.read_csv(r"C:\Users\ibrah\OneDrive\Desktop\Data Science\Pandas\archive\Ecommerce Purchases")

# %%
kf[['CC Exp Month' ,'CC Exp Year']] = kf['CC Exp Date'].str.split('/',expand = True)

# %%
kf.head()
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# ...

# %%
len(kf.loc[kf['CC Exp Year'] == '20'])
# Out:
# 988

# %%
len(df.loc[df['CC Exp Date'].apply(lambda x:x[3:] == '20')])
# Out:
# 988

# %% [markdown]
# #### Q15. What are the top 5 most popular email providers (e.g. gmail.com, yahoo.com, etc...)

# %%
df[['E_name','E_provider']] = df['Email'].str.split('@',expand = True)

# %%
df.head()
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# ...

# %%
gb = df.groupby(df.E_provider)

# %%
for x,rows in gb:
    print(x)
    print(rows)
# Out:
# acevedo-osborn.com
#                                                 Address    Lot AM or PM  \
# 8676  62056 Anderson Fort Suite 150\nSouth Katherine...  63 Qn       AM
#
#                                            Browser Info  \
# 8676  Mozilla/5.0 (X11; Linux i686; rv:1.9.5.20) Gec...
#
#                           Company       Credit Card CC Exp Date  \
# 8676  Martinez, Wilson and Jacobs  4781478519992148       06/24
#
#       CC Security Code CC Provider                         Email  \
# 8676               434    Discover  jeffery47@acevedo-osborn.com
#
#                       Job     IP Address Language  Purchase Price  \
# 8676  Seismic interpreter  37.234.95.179       es           70.01
#
#       CC Exp Year  CC Exp Month     E_name          E_provider
# 8676            1             0  jeffery47  acevedo-osborn.com
# acevedo-pena.biz
#                                                Address    Lot AM or PM  \
# ...

# %%
gb.get_group('yahoo.com')
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 6        93971 Conway Causeway\nAndersonburgh, AZ 75107  96 Xt       AM
# 13    118 Melton Via Suite 681\nAlexanderbury, FL 32104  36 bu       PM
# 14    8774 Jason Keys Suite 427\nEast Scottborough, ...  70 zH       AM
# 15       31730 Chelsea Crest\nBlakemouth, CT 90395-0620  41 Cj       PM
# ...                                                 ...    ...      ...
# 9958                   PSC 8781, Box 4214\nAPO AP 94478  72 Ez       AM
# 9973     92126 Daniel Streets\nNorth Patricia, IA 10477  04 QN       PM
# 9974     500 Powell Rapid Apt. 114\nClarkfort, FL 70488  48 is       AM
# 9977  02182 Keith Expressway\nEast Shannon, CT 20578...  34 RL       AM
# 9979  00490 Joseph Haven Apt. 149\nWest Keithfurt, S...  69 XK       PM
#
#                                            Browser Info  \
# ...

# %%
gb.describe()
# Out:
#                     Credit Card                                                \
#                           count          mean std           min           25%
# E_provider
# acevedo-osborn.com          1.0  4.781479e+15 NaN  4.781479e+15  4.781479e+15
# acevedo-pena.biz            1.0  8.699555e+14 NaN  8.699555e+14  8.699555e+14
# acosta.biz                  1.0  1.800130e+14 NaN  1.800130e+14  1.800130e+14
# acosta.com                  1.0  3.158120e+15 NaN  3.158120e+15  3.158120e+15
# adams-garcia.net            1.0  1.800815e+14 NaN  1.800815e+14  1.800815e+14
# ...                         ...           ...  ..           ...           ...
# zavala.org                  1.0  4.261830e+15 NaN  4.261830e+15  4.261830e+15
# zhang.biz                   1.0  4.420372e+12 NaN  4.420372e+12  4.420372e+12
# zhang.com                   1.0  3.337192e+15 NaN  3.337192e+15  3.337192e+15
# zimmerman-clark.com         1.0  4.310801e+12 NaN  4.310801e+12  4.310801e+12
# ...

# %%
df['E_provider'].value_counts().head()
# Out:
# E_provider
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: count, dtype: int64

# %%
list=[]
for email in df['Email']:
    list.append(email.split('@')[1])

# %%
df['temp'] = list

# %%
df['temp'].value_counts().head(5)
# Out:
# temp
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: count, dtype: int64
