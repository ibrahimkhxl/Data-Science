# %% [markdown]
# # Given in the dataset we have year and avg income in canada. we need to use linear model and finf the avg income in year 2020

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv(r"canada_per_capita_income.csv")

# %%
df.head()
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
# %matplotlib inline
plt.xlabel("Year")
plt.ylabel("Income")
plt.title(" Canada per capita income (US$)")
plt.scatter(df.year,df['per capita income (US$)'])

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['year']],df['per capita income (US$)'])
# Out:
# LinearRegression()

# %%
x = reg.predict([[2020]])
x
# Out:
# C:\Users\ibrah\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41288.69409442])

# %%
print("The per capita income for Year 2020 is",x,"$")
# Out:
# The per capita income for Year 2020 is [41288.69409442] $

# %%
reg.predict([[2003]])
# Out:
# C:\Users\ibrah\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([27204.78781563])

# %%
# %matplotlib inline
plt.xlabel("Year")
plt.ylabel("Income")
plt.scatter(df.year,df['per capita income (US$)'],color = 'red')
plt.plot(df.year,reg.predict(df[['year']]))
