# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\ibrah\OneDrive\Desktop\Workshop\Pandas_Keith\pokemon_data.csv")
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# To see the columns

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# ### Reading the Headers

# %%
# Reading headers
print(df.columns)

#  reading each column
print(df['Name'][:5])
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object

# %%
print(df.Attack[:5])
# Out:
# 0     49
# 1     62
# 2     82
# 3    100
# 4     52
# Name: Attack, dtype: int64

# %%
df[2:5]
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total Status  count
# 2      100     80         999      False    526  Great      1
# 3      120     80         999      False    626  Great      1
# 4       50     65           1      False    310   Good      1

# %%
#  reading each row
df.iloc[1:9]
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 1  2                    Ivysaur  Grass  Poison  60      62       63       80
# 2  3                   Venusaur  Grass  Poison  80      82       83      100
# 3  3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
#
#    Sp. Def  Speed  Generation  Legendary
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False
# 5       65     80           1      False
# ...

# %%
#  iloc is used to print a specific row or all rows iloc[rows,columns]
print(df.iloc[2,1])

print(df.iloc[6,:])
# Out:
# Venusaur
# #                     6
# Name          Charizard
# Type 1             Fire
# Type 2           Flying
# HP                   78
# Attack               84
# Defense              78
# Sp. Atk             109
# Sp. Def              85
# Speed               100
# Generation            1
# Legendary         False
# Name: 6, dtype: object

# %% [markdown]
# to itterate rows

# %%
for index,rows in df.iterrows():
    print(index,rows['Name'])
# Out:
# 0 Bulbasaur
# 1 Ivysaur
# 2 Venusaur
# 3 VenusaurMega Venusaur
# 4 Charmander
# 5 Charmeleon
# 6 Charizard
# 7 CharizardMega Charizard X
# 8 CharizardMega Charizard Y
# 9 Squirtle
# 10 Wartortle
# 11 Blastoise
# 12 BlastoiseMega Blastoise
# 13 Caterpie
# 14 Metapod
# 15 Butterfree
# 16 Weedle
# 17 Kakuna
# 18 Beedrill
# 19 BeedrillMega Beedrill
# 20 Pidgey
# 21 Pidgeotto
# 22 Pidgeot
# 23 PidgeotMega Pidgeot
# 24 Rattata
# 25 Raticate
# 26 Spearow
# 27 Fearow
# 28 Ekans
# 29 Arbok
# 30 Pikachu
# 31 Raichu
# 32 Sandshrew
# 33 Sandslash
# 34 Nidoran (Female)
# 35 Nidorina
# 36 Nidoqueen
# 37 Nidoran (Male)
# 38 Nidorino
# 39 Nidoking
# 40 Clefairy
# 41 Clefable
# 42 Vulpix
# 43 Ninetales
# 44 Jigglypuff
# 45 Wigglytuff
# 46 Zubat
# 47 Golbat
# 48 Oddish
# 49 Gloom
# 50 Vileplume
# 51 Paras
# 52 Parasect
# 53 Venonat
# 54 Venomoth
# 55 Diglett
# 56 Dugtrio
# 57 Meowth
# 58 Persian
# 59 Psyduck
# 60 Golduck
# 61 Mankey
# 62 Primeape
# 63 Growlithe
# 64 Arcanine
# 65 Poliwag
# ...

# %% [markdown]
# For reading only specific data types

# %%
df.loc[df['Type 1'] == "Fire"].head(5)
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
#
#    Sp. Def  Speed  Generation  Legendary
# 4       50     65           1      False
# 5       65     80           1      False
# 6       85    100           1      False
# 7       85    100           1      False
# 8      115    100           1      False

# %%
df.loc[df.HP == 39].head(5)
# Out:
#        #        Name Type 1 Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 4      4  Charmander   Fire    NaN  39      52       43       60       50
# 169  155   Cyndaquil   Fire    NaN  39      52       43       60       50
#
#      Speed  Generation  Legendary
# 4       65           1      False
# 169     65           2      False

# %%
df.loc[df['Type 2'] == 'Flying'].head()
# Out:
#      #                       Name  Type 1  Type 2  HP  Attack  Defense  \
# 6    6                  Charizard    Fire  Flying  78      84       78
# 8    6  CharizardMega Charizard Y    Fire  Flying  78     104       78
# 15  12                 Butterfree     Bug  Flying  60      45       50
# 20  16                     Pidgey  Normal  Flying  40      45       40
# 21  17                  Pidgeotto  Normal  Flying  63      60       55
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 6       109       85    100           1      False
# 8       159      115    100           1      False
# 15       90       80     70           1      False
# 20       35       35     56           1      False
# 21       50       50     71           1      False

# %%
df[df['Type 1'] == 'Bug'].sum
# Out:
# <bound method DataFrame.sum of        #        Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 13    10    Caterpie    Bug     NaN  45      30       35       20       20
# 14    11     Metapod    Bug     NaN  50      20       55       25       25
# 15    12  Butterfree    Bug  Flying  60      45       50       90       80
# 16    13      Weedle    Bug  Poison  40      35       30       20       20
# 17    14      Kakuna    Bug  Poison  45      25       50       25       25
# ..   ...         ...    ...     ...  ..     ...      ...      ...      ...
# 698  637   Volcarona    Bug    Fire  85      60       65      135      105
# 717  649    Genesect    Bug   Steel  71     120       95      120       95
# 732  664  Scatterbug    Bug     NaN  38      35       40       27       25
# 733  665      Spewpa    Bug     NaN  45      22       60       27       30
# 734  666    Vivillon    Bug  Flying  80      52       50       90       50
#
#      Speed  Generation  Legendary
# ...

# %% [markdown]
#  Describe

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %% [markdown]
# Sorting

# %%
df.sort_values('Name',ascending = False).head(5)
# Out:
#        #              Name  Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 794  718  Zygarde50% Forme  Dragon  Ground  108     100      121       81
# 695  634          Zweilous    Dark  Dragon   72      85       70       65
# 46    41             Zubat  Poison  Flying   40      45       35       30
# 631  570             Zorua    Dark     NaN   40      65       40       80
# 632  571           Zoroark    Dark     NaN   60     105       60      120
#
#      Sp. Def  Speed  Generation  Legendary
# 794       95     95           6       True
# 695       70     58           5      False
# 46        40     55           1      False
# 631       40     65           5      False
# 632       60    105           5      False

# %%
df.sort_values(['Type 1','HP'],ascending = True).tail(5)
# Out:
#        #       Name Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 142  131     Lapras  Water    Ice  130      85       80       85       95
# 145  134   Vaporeon  Water    NaN  130      65       60      110       95
# 350  320    Wailmer  Water    NaN  130      70       35       70       35
# 655  594  Alomomola  Water    NaN  165      75       80       40       45
# 351  321    Wailord  Water    NaN  170      90       45       90       45
#
#      Speed  Generation  Legendary
# 142     60           1      False
# 145     65           1      False
# 350     60           3      False
# 655     65           5      False
# 351     60           3      False

# %% [markdown]
# ### Making Changes to dataset

# %%
df['Total'] = df['HP'] + df['Attack']

df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False     94
# 1       80     60           1      False    122
# 2      100     80           1      False    162
# 3      120     80           1      False    180
# 4       50     65           1      False     91

# %% [markdown]
# Droping a Column

# %%
df = df.drop(columns = ['Total'])

# %%
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df['Total'] = df.iloc[:,4:11].sum(axis = 1)
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    319
# 1       80     60           1      False    406
# 2      100     80           1      False    526
# 3      120     80           1      False    626
# 4       50     65           1      False    310

# %% [markdown]
# ### Filtering Data

# %% [markdown]
# Reset the Index

# %%
fdf = df.loc[(df["Type 1"] == "Grass") & (df["Type 2"] == "Poison") & (df['HP'] >= 40)]
fdf.reset_index(inplace = True)
fdf
# Out:
#     index    #                   Name Type 1  Type 2   HP  Attack  Defense  \
# 0       0    1              Bulbasaur  Grass  Poison   45      49       49
# 1       1    2                Ivysaur  Grass  Poison   60      62       63
# 2       2    3               Venusaur  Grass  Poison   80      82       83
# 3       3    3  VenusaurMega Venusaur  Grass  Poison   80     100      123
# 4      48   43                 Oddish  Grass  Poison   45      50       55
# 5      49   44                  Gloom  Grass  Poison   60      65       70
# 6      50   45              Vileplume  Grass  Poison   75      80       85
# 7      75   69             Bellsprout  Grass  Poison   50      75       35
# 8      76   70             Weepinbell  Grass  Poison   65      90       50
# 9      77   71             Victreebel  Grass  Poison   80     105       65
# 10    344  315                Roselia  Grass  Poison   50      60       45
# ...

# %% [markdown]
# ### To Update the CSV

# %%
fdf.to_csv("Filterxxx.csv")

# %% [markdown]
# To Check if any row contains any typw of word

# %%
df.loc[df['Name'].str.contains("gus")]
# Out:
#        #        Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 624  563  Cofagrigus  Ghost     NaN   58      50      145       95      105
# 651  590     Foongus  Grass  Poison   69      55       45       55       55
# 652  591   Amoonguss  Grass  Poison  114      85       70       85       80
#
#      Speed  Generation  Legendary  Total
# 624     30           5      False    488
# 651     15           5      False    299
# 652     30           5      False    469

# %%
df.loc[df['Name'].str.contains('pi')].head(5)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
#  12  Total       800 non-null    int64
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %%
df.dropna()
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 6      6              Charizard     Fire  Flying  78      84       78
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0         65       65     45           1      False    319
# ...

# %%
df.loc[df['Total'] > 500 , ['Generation']] = 999
df.drop(columns=['Status'])
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total  count
# ...

# %%
df.loc[df['Total'] > 500 ,['Status']] = "Great"
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total Status
# 0       65     45           1      False    319    NaN
# 1       80     60           1      False    406    NaN
# 2      100     80         999      False    526  Great
# 3      120     80         999      False    626  Great
# 4       50     65           1      False    310    NaN

# %%
df['Status'].fillna('Good',inplace = True)
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total Status
# ...

# %%
df.reset_index().drop(columns = ['#'])
df['count'] = 1
dff = df.groupby(['Type 1']).count()['count']
dff
# Out:
# Type 1
# Bug          69
# Dark         31
# Dragon       32
# Electric     44
# Fairy        17
# Fighting     27
# Fire         52
# Flying        4
# Ghost        32
# Grass        70
# Ground       32
# Ice          24
# Normal       98
# Poison       28
# Psychic      57
# Rock         44
# Steel        27
# Water       112
# Name: count, dtype: int64

# %% [markdown]
# ### Aggerate Statistics (Group By)

# %%
g = df.groupby('Type 1')
print(g)

# %%
tt = df['Type 1']
for tt,typ1 in g:
    print(tt)
    print(typ1.reset_index())
# Out:
# Bug
#     index    #        Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0      13   10    Caterpie    Bug     NaN  45      30       35       20
# 1      14   11     Metapod    Bug     NaN  50      20       55       25
# 2      15   12  Butterfree    Bug  Flying  60      45       50       90
# 3      16   13      Weedle    Bug  Poison  40      35       30       20
# 4      17   14      Kakuna    Bug  Poison  45      25       50       25
# ..    ...  ...         ...    ...     ...  ..     ...      ...      ...
# 64    698  637   Volcarona    Bug    Fire  85      60       65      135
# 65    717  649    Genesect    Bug   Steel  71     120       95      120
# 66    732  664  Scatterbug    Bug     NaN  38      35       40       27
# 67    733  665      Spewpa    Bug     NaN  45      22       60       27
# 68    734  666    Vivillon    Bug  Flying  80      52       50       90
#
#     Sp. Def  Speed  Generation  Legendary  Total Status
# ...

# %%
gg=g.get_group('Fire').head()
gg.reset_index().drop(columns = ['index','#'])
gg
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
#
#    Sp. Def  Speed  Generation  Legendary  Total Status
# 4       50     65           1      False    310   Good
# 5       65     80           1      False    406   Good
# 6       85    100         999      False    535  Great
# 7       85    100         999      False    635  Great
# 8      115    100         999      False    635  Great

# %%
ff = read_csv()
