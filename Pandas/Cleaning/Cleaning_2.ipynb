# %%
import pandas as pd
import numpy as np

# %%
people = {
    'first': ['Corey', 'Jane', 'John', 'Chris', np.nan, None, 'NA'], 
    'last': ['Schafer', 'Doe', 'Doe', 'Schafer', np.nan, np.nan, 'Missing'], 
    'email': ['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com', None, np.nan, 'Anonymous@email.com', 'NA'],
    'age': ['33', '55', '63', '36', None, None, 'Missing']
}

# %%
df = pd.DataFrame(people)
df
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 4    NaN      NaN                      NaN     None
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %%
df.isna().sum()
# Out:
# first    2
# last     2
# email    2
# age      2
# dtype: int64

# %%
dff = df.dropna(axis = 0, thresh = 2)

# %%
dff.reset_index().drop(columns = 'index',axis = 0,inplace = True)

# %%
dff.reset_index()
# Out:
#    index  first     last                    email      age
# 0      0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1      1   Jane      Doe        JaneDoe@email.com       55
# 2      2   John      Doe        JohnDoe@email.com       63
# 3      3  Chris  Schafer                     None       36
# 4      6     NA  Missing                       NA  Missing

# %%
df
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 4    NaN      NaN                      NaN     None
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %%
df2 = df.dropna(axis = 0 , how = 'all',subset = ['email','last'])

# %%
df2
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %%
df2.replace('NA',np.nan,inplace = True)
# Out:
# C:\Users\ibrah\AppData\Local\Temp\ipykernel_105616\3425270861.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.replace('NA',np.nan,inplace = True)

# %%
df2.replace('Missing',np.nan,inplace = True)
# Out:
# C:\Users\ibrah\AppData\Local\Temp\ipykernel_105616\3883074590.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.replace('Missing',np.nan,inplace = True)

# %%
df2
# Out:
#    first     last                    email   age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com    33
# 1   Jane      Doe        JaneDoe@email.com    55
# 2   John      Doe        JohnDoe@email.com    63
# 3  Chris  Schafer                     None    36
# 5   None      NaN      Anonymous@email.com  None
# 6    NaN      NaN                      NaN   NaN

# %%
df2.age.fillna(0,inplace = True)
# Out:
# C:\Users\ibrah\AppData\Local\Temp\ipykernel_105616\4152305445.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.age.fillna(0,inplace = True)

# %%
df2.age = df2.age.astype(int)
# Out:
# C:\Users\ibrah\AppData\Local\Temp\ipykernel_105616\4200615110.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.age = df2.age.astype(int)

# %%
type(df2.age[1])
# Out:
# numpy.int32

# %%
df2.age.mean()
# Out:
# 31.166666666666668

# %%
df2.age.replace(0,df2.age.mean(),inplace = True)
# Out:
# C:\Users\ibrah\AppData\Local\Temp\ipykernel_105616\1345932677.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.age.replace(0,df2.age.mean(),inplace = True)

# %%
df2.age = df2.age.astype(int)
# Out:
# C:\Users\ibrah\AppData\Local\Temp\ipykernel_105616\4200615110.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.age = df2.age.astype(int)

# %%
df2
# Out:
#    first     last                    email  age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com   33
# 1   Jane      Doe        JaneDoe@email.com   55
# 2   John      Doe        JohnDoe@email.com   63
# 3  Chris  Schafer                     None   36
# 5   None      NaN      Anonymous@email.com   31
# 6    NaN      NaN                      NaN   31

# %%
df
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 4    NaN      NaN                      NaN        0
# 5   None      NaN      Anonymous@email.com        0
# 6     NA  Missing                       NA  Missing

# %%
na_vals = ['NA','Missing']
df.replace(na_vals,np.nan)
# Out:
#    first     last                    email  age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com   33
# 1   Jane      Doe        JaneDoe@email.com   55
# 2   John      Doe        JohnDoe@email.com   63
# 3  Chris  Schafer                     None   36
# 4    NaN      NaN                      NaN    0
# 5   None      NaN      Anonymous@email.com    0
# 6    NaN      NaN                      NaN  NaN

# %% [markdown]
# # Stack over Cleaning 1

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\ibrah\OneDrive\Desktop\Data Science\Pandas\stack-overflow-developer-survey-2022\survey_results_schema.csv")

# %%
df
# Out:
#        qid        qname                                           question  \
# 0    QID16           S0  <div><span style="font-size:19px;"><strong>Hel...
# 1    QID12     MetaInfo                                  Browser Meta Info
# 2     QID1           S1  <span style="font-size:22px; font-family: aria...
# 3     QID2   MainBranch  Which of the following options best describes ...
# 4   QID296   Employment  Which of the following best describes your cur...
# ..     ...          ...                                                ...
# 74  QID290  Frequency_2  Interacting with people outside of your immedi...
# 75  QID290  Frequency_3  Encountering knowledge silos (where one indivi...
# 76  QID294  TrueFalse_1  Are you involved in supporting new hires durin...
# 77  QID294  TrueFalse_2  Do you use learning resources provided by your...
# 78  QID294  TrueFalse_3  Does your employer give you time to learn new ...
#
#    force_resp  type selector
# 0       False    DB       TB
# ...

# %%
df.head(20)
# Out:
#        qid                 qname  \
# 0    QID16                    S0
# 1    QID12              MetaInfo
# 2     QID1                    S1
# 3     QID2            MainBranch
# 4   QID296            Employment
# 5   QID308            RemoteWork
# 6   QID297      CodingActivities
# 7   QID190                    S2
# 8    QID25               EdLevel
# 9   QID276             LearnCode
# 10  QID281       LearnCodeOnline
# 11  QID306  LearnCodeCoursesCert
# 12   QID32             YearsCode
# 13   QID34          YearsCodePro
# 14   QID31               DevType
# 15   QID29               OrgSize
# 16  QID278     PurchaseInfluence
# 17  QID279            BuyNewTool
# 18    QID6               Country
# 19   QID50              Currency
#
#                                              question force_resp  type  \
# 0   <div><span style="font-size:19px;"><strong>Hel...      False    DB
# 1                                   Browser Meta Info      False  Meta
# ...

# %%
df.tail(10)
# Out:
#        qid        qname                                           question  \
# 69  QID289  Knowledge_4  I am able to quickly find answers to my questi...
# 70  QID289  Knowledge_5  I know which system or resource to use to find...
# 71  QID289  Knowledge_6  I often find myself answering questions that I...
# 72  QID289  Knowledge_7  Waiting on answers to questions often causes i...
# 73  QID290  Frequency_1  Needing help from people outside of your immed...
# 74  QID290  Frequency_2  Interacting with people outside of your immedi...
# 75  QID290  Frequency_3  Encountering knowledge silos (where one indivi...
# 76  QID294  TrueFalse_1  Are you involved in supporting new hires durin...
# 77  QID294  TrueFalse_2  Do you use learning resources provided by your...
# 78  QID294  TrueFalse_3  Does your employer give you time to learn new ...
#
#    force_resp type selector
# 69        NaN   MC     MAVR
# 70        NaN   MC     MAVR
# 71        NaN   MC     MAVR
# ...

# %%
df.columns
# Out:
# Index(['qid', 'qname', 'question', 'force_resp', 'type', 'selector'], dtype='object')

# %%
df.dropna()
# Out:
#        qid         qname                                           question  \
# 0    QID16            S0  <div><span style="font-size:19px;"><strong>Hel...
# 1    QID12      MetaInfo                                  Browser Meta Info
# 2     QID1            S1  <span style="font-size:22px; font-family: aria...
# 3     QID2    MainBranch  Which of the following options best describes ...
# 4   QID296    Employment  Which of the following best describes your cur...
# ..     ...           ...                                                ...
# 61  QID286  SOTeamsUsage       Does your team use Stack Overflow for Teams?
# 62  QID294     TrueFalse                              Last few questions...
# 63  QID131            S7  <span style="font-size:22px;"><strong>Final Qu...
# 64  QID132  SurveyLength  How do you feel about the length of the survey...
# 65  QID133    SurveyEase  How easy or difficult was this survey to compl...
#
#    force_resp    type selector
# ...

# %%
df.fillna(0,inplace = True)

# %%
df.replace(0,'True',inplace =True)

# %%
df.tail(5)
# Out:
#        qid        qname                                           question  \
# 74  QID290  Frequency_2  Interacting with people outside of your immedi...
# 75  QID290  Frequency_3  Encountering knowledge silos (where one indivi...
# 76  QID294  TrueFalse_1  Are you involved in supporting new hires durin...
# 77  QID294  TrueFalse_2  Do you use learning resources provided by your...
# 78  QID294  TrueFalse_3  Does your employer give you time to learn new ...
#
#    force_resp type selector
# 74       True   MC     MAVR
# 75       True   MC     MAVR
# 76       True   MC     MAVR
# 77       True   MC     MAVR
# 78       True   MC     MAVR

# %% [markdown]
# ### Stack overflow clening 2

# %%
df = pd.read_csv(r"C:\Users\ibrah\OneDrive\Desktop\Data Science\Pandas\stack-overflow-developer-survey-2022\survey_results_public.csv")

# %%
df.head(20)
# Out:
#     ResponseId                                         MainBranch  \
# 0            1                                      None of these
# 1            2                     I am a developer by profession
# 2            3  I am not primarily a developer, but I write co...
# 3            4                     I am a developer by profession
# 4            5                     I am a developer by profession
# 5            6  I am not primarily a developer, but I write co...
# 6            7                        I code primarily as a hobby
# 7            8                     I am a developer by profession
# 8            9                     I am a developer by profession
# 9           10                     I am a developer by profession
# 10          11                     I am a developer by profession
# 11          12  I am not primarily a developer, but I write co...
# 12          13                     I am a developer by profession
# ...

# %%
df.tail(10)
# Out:
#        ResponseId                                         MainBranch  \
# 73258       73259                     I am a developer by profession
# 73259       73260                     I am a developer by profession
# 73260       73261                     I am a developer by profession
# 73261       73262                     I am a developer by profession
# 73262       73263                              I am learning to code
# 73263       73264                     I am a developer by profession
# 73264       73265                     I am a developer by profession
# 73265       73266  I am not primarily a developer, but I write co...
# 73266       73267                     I am a developer by profession
# 73267       73268  I used to be a developer by profession, but no...
#
#                                               Employment  \
# 73258                                Employed, full-time
# 73259                                Employed, full-time
# ...

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'BuyNewTool', 'Country', 'Currency',
#        'CompTotal', 'CompFreq', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysProfessional use',
#        'OpSysPersonal use', 'VersionControlSystem', 'VCInteraction',
#        'VCHostingPersonal use', 'VCHostingProfessional use',
#        'OfficeStackAsyncHaveWorkedWith', 'OfficeStackAsyncWantToWorkWith',
# ...

# %%
df2 = df.drop(df.columns[10:], axis=1)
df2
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                                      None of these
# 1               2                     I am a developer by profession
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 73263       73264                     I am a developer by profession
# 73264       73265                     I am a developer by profession
# 73265       73266  I am not primarily a developer, but I write co...
# 73266       73267                     I am a developer by profession
# 73267       73268  I used to be a developer by profession, but no...
#
#                                               Employment  \
# 0                                                    NaN
# ...

# %%
df2.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode'],
#       dtype='object')

# %%
df2.head(10)
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                                      None of these
# 1           2                     I am a developer by profession
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
# 5           6  I am not primarily a developer, but I write co...
# 6           7                        I code primarily as a hobby
# 7           8                     I am a developer by profession
# 8           9                     I am a developer by profession
# 9          10                     I am a developer by profession
#
#                                           Employment  \
# 0                                                NaN
# 1                                Employed, full-time
# 2                                Employed, full-time
# ...

# %%
df2.tail(10)
# Out:
#        ResponseId                                         MainBranch  \
# 73258       73259                     I am a developer by profession
# 73259       73260                     I am a developer by profession
# 73260       73261                     I am a developer by profession
# 73261       73262                     I am a developer by profession
# 73262       73263                              I am learning to code
# 73263       73264                     I am a developer by profession
# 73264       73265                     I am a developer by profession
# 73265       73266  I am not primarily a developer, but I write co...
# 73266       73267                     I am a developer by profession
# 73267       73268  I used to be a developer by profession, but no...
#
#                                               Employment  \
# 73258                                Employed, full-time
# 73259                                Employed, full-time
# ...

# %%
df2.isna().sum()
# Out:
# ResponseId                  0
# MainBranch                  0
# Employment               1559
# RemoteWork              14310
# CodingActivities        14369
# EdLevel                  1697
# LearnCode                1688
# LearnCodeOnline         22583
# LearnCodeCoursesCert    43879
# YearsCode                1937
# dtype: int64

# %%
df_na = df2.dropna()

# %%
df_na.isna().sum()
# Out:
# ResponseId              0
# MainBranch              0
# Employment              0
# RemoteWork              0
# CodingActivities        0
# EdLevel                 0
# LearnCode               0
# LearnCodeOnline         0
# LearnCodeCoursesCert    0
# YearsCode               0
# dtype: int64

# %%
df_na.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19076 entries, 16 to 73267
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ResponseId            19076 non-null  int64
#  1   MainBranch            19076 non-null  object
#  2   Employment            19076 non-null  object
#  3   RemoteWork            19076 non-null  object
#  4   CodingActivities      19076 non-null  object
#  5   EdLevel               19076 non-null  object
#  6   LearnCode             19076 non-null  object
#  7   LearnCodeOnline       19076 non-null  object
#  8   LearnCodeCoursesCert  19076 non-null  object
#  9   YearsCode             19076 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 1.6+ MB

# %%
df_na.describe()
# Out:
#          ResponseId
# count  19076.000000
# mean   37378.358828
# std    20584.469121
# min       17.000000
# 25%    19723.000000
# 50%    37949.500000
# 75%    54501.000000
# max    73268.000000

# %%
df2.isna().sum()
# Out:
# ResponseId                  0
# MainBranch                  0
# Employment               1559
# RemoteWork              14310
# CodingActivities        14369
# EdLevel                  1697
# LearnCode                1688
# LearnCodeOnline         22583
# LearnCodeCoursesCert    43879
# YearsCode                1937
# dtype: int64

# %%
df2.head(40)
# Out:
#     ResponseId                                         MainBranch  \
# 0            1                                      None of these
# 1            2                     I am a developer by profession
# 2            3  I am not primarily a developer, but I write co...
# 3            4                     I am a developer by profession
# 4            5                     I am a developer by profession
# 5            6  I am not primarily a developer, but I write co...
# 6            7                        I code primarily as a hobby
# 7            8                     I am a developer by profession
# 8            9                     I am a developer by profession
# 9           10                     I am a developer by profession
# 10          11                     I am a developer by profession
# 11          12  I am not primarily a developer, but I write co...
# 12          13                     I am a developer by profession
# ...

# %%
na_vals = ['NA','Missing','Other','--']
df2.replace(na_vals,np.nan,inplace = True)

# %%
df2.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                                      None of these
# 1           2                     I am a developer by profession
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#             Employment                            RemoteWork  \
# 0                  NaN                                   NaN
# 1  Employed, full-time                          Fully remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
# 3  Employed, full-time                          Fully remote
# 4  Employed, full-time  Hybrid (some remote, some in-person)
#
#                            CodingActivities  \
# 0                                       NaN
# 1  Hobby;Contribute to open-source projects
# 2                                     Hobby
# ...

# %%
df2.loc[df['YearsCode'] == 'More than 50 years']
# Out:
#        ResponseId                                         MainBranch  \
# 77             78  I used to be a developer by profession, but no...
# 635           636                     I am a developer by profession
# 861           862                     I am a developer by profession
# 3679         3680  I am not primarily a developer, but I write co...
# 5471         5472  I am not primarily a developer, but I write co...
# ...           ...                                                ...
# 71663       71664  I used to be a developer by profession, but no...
# 71810       71811                     I am a developer by profession
# 72040       72041                        I code primarily as a hobby
# 72091       72092                     I am a developer by profession
# 72959       72960                     I am a developer by profession
#
#                                               Employment    RemoteWork  \
# ...

# %%
df2.YearsCode.unique()
# Out:
# array([nan, '14', '20', '8', '15', '3', '1', '6', '37', '5', '12', '22',
#        '11', '4', '7', '13', '36', '2', '25', '10', '40', '16', '27',
#        '24', '19', '9', '17', '18', '26', 'More than 50 years', '29',
#        '30', '32', 'Less than 1 year', '48', '45', '38', '39', '28', '23',
#        '43', '21', '41', '35', '50', '33', '31', '34', '46', '44', '42',
#        '47', '49'], dtype=object)

# %%
df2.YearsCode.replace('More than 50 years',51,inplace = True)

# %%
df2.YearsCode.unique()
# Out:
# array([nan, '14', '20', '8', '15', '3', '1', '6', '37', '5', '12', '22',
#        '11', '4', '7', '13', '36', '2', '25', '10', '40', '16', '27',
#        '24', '19', '9', '17', '18', '26', 50, '29', '30', '32', 0, '48',
#        '45', '38', '39', '28', '23', '43', '21', '41', '35', '50', '33',
#        '31', '34', '46', '44', '42', '47', '49'], dtype=object)

# %%
df2.YearsCode.replace('Less than 1 year',0,inplace = True)

# %%
df2.YearsCode.unique()
# Out:
# array([nan, '14', '20', '8', '15', '3', '1', '6', '37', '5', '12', '22',
#        '11', '4', '7', '13', '36', '2', '25', '10', '40', '16', '27',
#        '24', '19', '9', '17', '18', '26', 50, '29', '30', '32', 0, '48',
#        '45', '38', '39', '28', '23', '43', '21', '41', '35', '50', '33',
#        '31', '34', '46', '44', '42', '47', '49'], dtype=object)

# %%
df2.YearsCode.fillna(0,inplace = True)

# %%
df2.YearsCode = df2.YearsCode.astype(float)

# %%
type(df2.YearsCode[0])
# Out:
# numpy.float64

# %%
df2.YearsCode.mean()
# Out:
# 11.925069607468473

# %%
df2.YearsCode.median()
# Out:
# 9.0

# %%
df2.YearsCode.mode()
# Out:
# 0    10.0
# Name: YearsCode, dtype: float64
