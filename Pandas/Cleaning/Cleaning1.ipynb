# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'C:\Users\ibrah\OneDrive\Desktop\Workshop\DataScience\dataset.csv')
df.head(9)
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT  \
# 0  100001000.0   104.0      PUTNAM            Y          NaN        1  1000
# 1  100002000.0   197.0   LEXINGTON            N            3      1.5    --
# 2  100003000.0     NaN   LEXINGTON            N          NaN        1   850
# 3  100004000.0   201.0    BERKELEY           12            1      NaN   700
# 4          NaN   203.0    BERKELEY            Y          NaN        2  1600
# 5  100006000.0   207.0    BERKELEY            Y          NaN        1   800
# 6  100007000.0     NaN  WASHINGTON          NaN            3   HURLEY   950
# 7  100008000.0   213.0     TREMONT            Y            2        1   NaN
# 8  100009000.0   215.0     TREMONT            Y           na        2  1800
#
#    RATING
# 0     4.0
# 1     NaN
# 2     2.0
# 3     1.0
# 4     5.0
# 5     2.0
# 6     3.0
# 7     NaN
# 8     5.0

# %%
df.shape
# Out:
# (9, 8)

# %%
df.isna().sum()
# Out:
# PID             1
# ST_NUM          2
# ST_NAME         0
# OWN_OCCUPIED    1
# NUM_BEDROOMS    4
# NUM_BATH        1
# SQ_FT           1
# RATING          2
# dtype: int64

# %%
df.PID = df['PID'].interpolate()
df
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT  \
# 0  100001000.0   104.0      PUTNAM            Y          NaN        1  1000
# 1  100002000.0   197.0   LEXINGTON            N            3      1.5    --
# 2  100003000.0     NaN   LEXINGTON            N          NaN        1   850
# 3  100004000.0   201.0    BERKELEY           12            1      NaN   700
# 4  100005000.0   203.0    BERKELEY            Y          NaN        2  1600
# 5  100006000.0   207.0    BERKELEY            Y          NaN        1   800
# 6  100007000.0     NaN  WASHINGTON          NaN            3   HURLEY   950
# 7  100008000.0   213.0     TREMONT            Y            2        1   NaN
# 8  100009000.0   215.0     TREMONT            Y           na        2  1800
#
#    RATING
# 0     4.0
# 1     NaN
# 2     2.0
# 3     1.0
# 4     5.0
# 5     2.0
# 6     3.0
# 7     NaN
# 8     5.0

# %%
df.ST_NUM.median()
# Out:
# 203.0

# %%
df["ST_NUM"] = df['ST_NUM'].fillna(df.ST_NUM.median())

# %%
df
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT  \
# 0  100001000.0   104.0      PUTNAM            Y          NaN        1  1000
# 1  100002000.0   197.0   LEXINGTON            N            3      1.5    --
# 2  100003000.0   203.0   LEXINGTON            N          NaN        1   850
# 3  100004000.0   201.0    BERKELEY           12            1      NaN   700
# 4  100005000.0   203.0    BERKELEY            Y          NaN        2  1600
# 5  100006000.0   207.0    BERKELEY            Y          NaN        1   800
# 6  100007000.0   203.0  WASHINGTON          NaN            3   HURLEY   950
# 7  100008000.0   213.0     TREMONT            Y            2        1   NaN
# 8  100009000.0   215.0     TREMONT            Y           na        2  1800
#
#    RATING
# 0     4.0
# 1     NaN
# 2     2.0
# 3     1.0
# 4     5.0
# 5     2.0
# 6     3.0
# 7     NaN
# 8     5.0

# %%
# for OWN_OCCUPIED in df.loc[(df['OWN_OCCUPIED'] != 'Y') | (df['OWN_OCCUPIED'] != 'N')]:
    
#     df['OWN_OCCUPIED'] = "N"

# %%
df = df.replace({
    'OWN_OCCUPIED': '12'
},"N")

# %%
df['OWN_OCCUPIED'] = df['OWN_OCCUPIED'].fillna('N')

# %%
df
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT  \
# 0  100001000.0   104.0      PUTNAM            Y          NaN        1  1000
# 1  100002000.0   197.0   LEXINGTON            N            3      1.5    --
# 2  100003000.0   203.0   LEXINGTON            N          NaN        1   850
# 3  100004000.0   201.0    BERKELEY            N            1      NaN   700
# 4  100005000.0   203.0    BERKELEY            Y          NaN        2  1600
# 5  100006000.0   207.0    BERKELEY            Y          NaN        1   800
# 6  100007000.0   203.0  WASHINGTON            N            3   HURLEY   950
# 7  100008000.0   213.0     TREMONT            Y            2        1   NaN
# 8  100009000.0   215.0     TREMONT            Y           na        2  1800
#
#    RATING
# 0     4.0
# 1     NaN
# 2     2.0
# 3     1.0
# 4     5.0
# 5     2.0
# 6     3.0
# 7     NaN
# 8     5.0

# %%
df
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT  \
# 0  100001000.0   104.0      PUTNAM            Y          NaN        1  1000
# 1  100002000.0   197.0   LEXINGTON            N            3      1.5    --
# 2  100003000.0   203.0   LEXINGTON            N          NaN        1   850
# 3  100004000.0   201.0    BERKELEY            N            1      NaN   700
# 4  100005000.0   203.0    BERKELEY            Y          NaN        2  1600
# 5  100006000.0   207.0    BERKELEY            Y          NaN        1   800
# 6  100007000.0   203.0  WASHINGTON            N            3   HURLEY   950
# 7  100008000.0   213.0     TREMONT            Y            2        1   NaN
# 8  100009000.0   215.0     TREMONT            Y           na        2  1800
#
#    RATING
# 0     4.0
# 1     NaN
# 2     2.0
# 3     1.0
# 4     5.0
# 5     2.0
# 6     3.0
# 7     NaN
# 8     5.0

# %%
df.replace('na',np.nan,inplace = True)

# %%
df.head()
# Out:
#            PID  ST_NUM    ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT  \
# 0  100001000.0   104.0     PUTNAM            Y          NaN        1  1000
# 1  100002000.0   197.0  LEXINGTON            N            3      1.5    --
# 2  100003000.0   203.0  LEXINGTON            N          NaN        1   850
# 3  100004000.0   201.0   BERKELEY            N            1      NaN   700
# 4  100005000.0   203.0   BERKELEY            Y          NaN        2  1600
#
#    RATING
# 0     4.0
# 1     NaN
# 2     2.0
# 3     1.0
# 4     5.0

# %%
df['NUM_BEDROOMS'].fillna(0,inplace = True)

# %%
df
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT  \
# 0  100001000.0   104.0      PUTNAM            Y            0        1  1000
# 1  100002000.0   197.0   LEXINGTON            N            3      1.5    --
# 2  100003000.0   203.0   LEXINGTON            N            0        1   850
# 3  100004000.0   201.0    BERKELEY            N            1      NaN   700
# 4  100005000.0   203.0    BERKELEY            Y            0        2  1600
# 5  100006000.0   207.0    BERKELEY            Y            0        1   800
# 6  100007000.0   203.0  WASHINGTON            N            3   HURLEY   950
# 7  100008000.0   213.0     TREMONT            Y            2        1   NaN
# 8  100009000.0   215.0     TREMONT            Y            0        2  1800
#
#    RATING
# 0     4.0
# 1     NaN
# 2     2.0
# 3     1.0
# 4     5.0
# 5     2.0
# 6     3.0
# 7     NaN
# 8     5.0

# %%
df.NUM_BATH.replace(['HURLEY','1.5'],np.nan,inplace = True)
df.SQ_FT.replace('--',np.nan,inplace = True)

# %%
df['NUM_BEDROOMS'] = df['NUM_BEDROOMS'].astype(int)

# %%
type(df.NUM_BEDROOMS[4])
# Out:
# numpy.int32

# %%
type(df.NUM_BATH[0])
# Out:
# str

# %%
# df['NUM_BATH'] = df['NUM_BATH'].astype(int)

# %%
df
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS NUM_BATH SQ_FT  \
# 0  100001000.0   104.0      PUTNAM            Y             0        1  1000
# 1  100002000.0   197.0   LEXINGTON            N             3      NaN   NaN
# 2  100003000.0   203.0   LEXINGTON            N             0        1   850
# 3  100004000.0   201.0    BERKELEY            N             1      NaN   700
# 4  100005000.0   203.0    BERKELEY            Y             0        2  1600
# 5  100006000.0   207.0    BERKELEY            Y             0        1   800
# 6  100007000.0   203.0  WASHINGTON            N             3      NaN   950
# 7  100008000.0   213.0     TREMONT            Y             2        1   NaN
# 8  100009000.0   215.0     TREMONT            Y             0        2  1800
#
#    RATING
# 0     4.0
# 1     NaN
# 2     2.0
# 3     1.0
# 4     5.0
# 5     2.0
# 6     3.0
# 7     NaN
# 8     5.0

# %%
df.NUM_BATH.fillna(2,inplace = True)

# %%
df.NUM_BATH = df.NUM_BATH.astype(int)

# %%
df.SQ_FT = df.SQ_FT.astype(float)

# %%
df['SQ_FT'].fillna(df['SQ_FT'].mean(),inplace = True)

# %%
df.RATING = df.RATING.astype(float)

# %%
df['RATING'].fillna(df['RATING'].mean(),inplace = True)

# %%
df.RATING = df.RATING.astype(int)
df.SQ_FT = df.SQ_FT.astype(int)

# %%
df.to_csv("modeifed_dataset")

# %%
df
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS  NUM_BATH  \
# 0  100001000.0   104.0      PUTNAM            Y             0         1
# 1  100002000.0   197.0   LEXINGTON            N             3         2
# 2  100003000.0   203.0   LEXINGTON            N             0         1
# 3  100004000.0   201.0    BERKELEY            N             1         2
# 4  100005000.0   203.0    BERKELEY            Y             0         2
# 5  100006000.0   207.0    BERKELEY            Y             0         1
# 6  100007000.0   203.0  WASHINGTON            N             3         2
# 7  100008000.0   213.0     TREMONT            Y             2         1
# 8  100009000.0   215.0     TREMONT            Y             0         2
#
#    SQ_FT  RATING
# 0   1000       4
# 1   1100       3
# 2    850       2
# 3    700       1
# 4   1600       5
# 5    800       2
# 6    950       3
# 7   1100       3
# 8   1800       5

# %%
gb = df.groupby('ST_NAME')
gb

# %%
for x,st in gb:
    print(x)
    print(st.reset_index().drop(columns = 'index',axis = 0))
# Out:
# BERKELEY
#            PID  ST_NUM   ST_NAME OWN_OCCUPIED  NUM_BEDROOMS  NUM_BATH  SQ_FT  \
# 0  100004000.0   201.0  BERKELEY            N             1         2    700
# 1  100005000.0   203.0  BERKELEY            Y             0         2   1600
# 2  100006000.0   207.0  BERKELEY            Y             0         1    800
#
#    RATING
# 0       1
# 1       5
# 2       2
# LEXINGTON
#            PID  ST_NUM    ST_NAME OWN_OCCUPIED  NUM_BEDROOMS  NUM_BATH  SQ_FT  \
# 0  100002000.0   197.0  LEXINGTON            N             3         2   1100
# 1  100003000.0   203.0  LEXINGTON            N             0         1    850
#
#    RATING
# 0       3
# 1       2
# PUTNAM
#            PID  ST_NUM ST_NAME OWN_OCCUPIED  NUM_BEDROOMS  NUM_BATH  SQ_FT  \
# 0  100001000.0   104.0  PUTNAM            Y             0         1   1000
#
#    RATING
# 0       4
# TREMONT
#            PID  ST_NUM  ST_NAME OWN_OCCUPIED  NUM_BEDROOMS  NUM_BATH  SQ_FT  \
# ...

# %%
gb.describe()
# Out:
#              PID                                                      \
#            count         mean          std          min          25%
# ST_NAME
# BERKELEY     3.0  100005000.0  1000.000000  100004000.0  100004500.0
# LEXINGTON    2.0  100002500.0   707.106781  100002000.0  100002250.0
# PUTNAM       1.0  100001000.0          NaN  100001000.0  100001000.0
# TREMONT      2.0  100008500.0   707.106781  100008000.0  100008250.0
# WASHINGTON   1.0  100007000.0          NaN  100007000.0  100007000.0
#
#                                                   ST_NUM              ...  \
#                     50%          75%          max  count        mean  ...
# ST_NAME                                                               ...
# BERKELEY    100005000.0  100005500.0  100006000.0    3.0  203.666667  ...
# LEXINGTON   100002500.0  100002750.0  100003000.0    2.0  200.000000  ...
# PUTNAM      100001000.0  100001000.0  100001000.0    1.0  104.000000  ...
# ...
